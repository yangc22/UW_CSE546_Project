# %%
import pandas as pd
import math
import csv
import random
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
base_elo = 1600
team_elos = {} 
team_stats = {}
X = []
y = []
# folder = '/Users/chaoyiyang/Documents/Course/CSE546-Machine Learning-18Au/Project/Data/' #directory to save the result
folder = '/Users/chaoyiyang/Documents/Course/CSE546-Machine Learning-18Au/Project/Data/UW_CSE546_Project/ELO Rating/training_data'

# %%
# based on Miscellaneous Opponent，Team stats to initialize
def initialize_data(Mstat, Ostat, Tstat):
    new_Mstat = Mstat.drop(['Rk', 'Arena'], axis=1)
    new_Ostat = Ostat.drop(['Rk', 'G', 'MP'], axis=1)
    new_Tstat = Tstat.drop(['Rk', 'G', 'MP'], axis=1)

    team_stats1 = pd.merge(new_Mstat, new_Ostat, how='left', on='Team')
    team_stats1 = pd.merge(team_stats1, new_Tstat, how='left', on='Team')

    print(team_stats1.info())
    return team_stats1.set_index('Team', inplace=False, drop=True)

# get the elo rating of each team
def get_elo(team):
    try:
        return team_elos[team]
    except:
        # initially set as base_elo
        team_elos[team] = base_elo
        return team_elos[team]
    
# calculate the ELO rating of each team
def calc_elo(win_team, lose_team):
    winner_rank = get_elo(win_team)
    loser_rank = get_elo(lose_team)

    rank_diff = winner_rank - loser_rank
    exp = (rank_diff  * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    # update the ELO rating
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    new_winner_rank = round(winner_rank + (k * (1 - odds)))
    new_rank_diff = new_winner_rank - winner_rank
    new_loser_rank = loser_rank - new_rank_diff

    return new_winner_rank, new_loser_rank

def  build_dataSet(all_data):
    print("Building data set..")
    for index, row in all_data.iterrows():

        Wteam = row['WTeam']
        Lteam = row['LTeam']

        # get the initial elo rating of each team
        team1_elo = get_elo(Wteam)
        team2_elo = get_elo(Lteam)

        # add 100 rating to the home team
        if row['WLoc'] == 'H':
            team1_elo += 100
        else:
            team2_elo += 100

        # set elo rating as the first feature
        team1_features = [team1_elo]
        team2_features = [team2_elo]

        # add the stats of each team
        for key, value in team_stats.loc[Wteam].iteritems():
            team1_features.append(value)
        for key, value in team_stats.loc[Lteam].iteritems():
            team2_features.append(value)

        # randomly set the order of features of each game for two team
        # give the corrsponding label
        # 0 as the latter team lose
        # 1 as the latter team win
        if random.random() > 0.5:
            X.append(team1_features + team2_features)
            y.append(0)
        else:
            X.append(team2_features + team1_features)
            y.append(1)

        # update the elo rating
        new_winner_rank, new_loser_rank = calc_elo(Wteam, Lteam)
        team_elos[Wteam] = new_winner_rank
        team_elos[Lteam] = new_loser_rank

    return np.nan_to_num(X), np.array(y)

def predict_winner(team_1, team_2, model):
    features = []

    # team 1，visitor team
    features.append(get_elo(team_1))
    for key, value in team_stats.loc[team_1].iteritems():
        features.append(value)

    # team 2，home team
    features.append(get_elo(team_2) + 100)
    for key, value in team_stats.loc[team_2].iteritems():
        features.append(value)

    features = np.nan_to_num(features)
    return model.predict_proba([features])

# %%
def combine_data(folder, season1, season2):
    M_name = 'MiscellaneousStats'
    O_name = 'OpponentPerGameStats'
    T_name = 'TeamPerGameStats'
    file_format = 'csv'
    M1 = pd.read_csv("{}/{}_{}.{}".format(folder, M_name, season1, file_format))
    M2 = pd.read_csv("{}/{}_{}.{}".format(folder, M_name, season2, file_format))
    O1 = pd.read_csv("{}/{}_{}.{}".format(folder, O_name, season1, file_format))
    O2 = pd.read_csv("{}/{}_{}.{}".format(folder, O_name, season2, file_format))
    T1 = pd.read_csv("{}/{}_{}.{}".format(folder, T_name, season1, file_format))
    T2 = pd.read_csv("{}/{}_{}.{}".format(folder, T_name, season2, file_format))
    Mstat = M1.append(M2, ignore_index=True)
    Ostat = O1.append(O2, ignore_index=True)
    Tstat = T1.append(T2, ignore_index=True)
    return Mstat, Ostat, Tstat

def combine_results(folder, season1, season2):
    r_name = 'result'
    file_format = 'csv'
    r1 = pd.read_csv("{}/{}_{}.{}".format(folder, r_name, season1, file_format))
    r2 = pd.read_csv("{}/{}_{}.{}".format(folder, r_name, season2, file_format))
    # print(r2)
    result_data = r1.append(r2, ignore_index=True)
    return result_data

# %%
if __name__ == '__main__':
    '''
    Mstat = pd.read_csv(folder + '/MiscellaneousStats.csv')
    Ostat = pd.read_csv(folder + '/OpponentPerGameStats.csv')
    Tstat = pd.read_csv(folder + '/TeamPerGameStats.csv')
    '''
    folder = '/Users/chaoyiyang/Documents/Course/CSE546-Machine Learning-18Au/Project/Data/UW_CSE546_Project/ELO Rating/training_data'
    season1 = '1718'
    season2 = '1819'
    Mstat, Ostat, Tstat = combine_data(folder, season1, season2)

    team_stats = initialize_data(Mstat, Ostat, Tstat)
    
    # result_data = pd.read_csv(folder + '/2017-18_result.csv')
    result_data = combine_results(folder, season1, season2)
    X_data, y_data = build_dataSet(result_data)

    # tarin the model
    print("Fitting on %d game samples.." % len(X))

    model = LogisticRegression()
    model.fit(X_data, y_data)

    # cross validation
    print("Doing cross-validation..")
    print(cross_val_score(model, X_data, y_data, cv = 10, scoring='accuracy', n_jobs=-1).mean())


    # predict on the new season
    print('Predicting on new schedule..')
    test_file = 'test_1819'
    test_format = 'csv'
    schedule1819 = pd.read_csv("{}/{}.{}".format(folder, test_file, test_format))
    result = []
    for index, row in schedule1819.iterrows():
        team1 = row['VTeam']
        team2 = row['HTeam']
        pred = predict_winner(team1, team2, model)
        prob = pred[0][0]
        if prob > 0.5:
            winner = team1
            loser = team2
            result.append([winner, loser, prob])
        else:
            winner = team2
            loser = team1
            result.append([winner, loser, 1 - prob])
    
    result_name = '1819_test_Result.csv'
    with open("{}/{}".format(foler, result_name), 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['win', 'lose', 'probability'])
        writer.writerows(result)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 68 columns):
# 3PAr         60 non-null float64
# Age          60 non-null float64
# Attend.      60 non-null float64
# Attend./G    60 non-null int64
# DRB%         60 non-null float64
# DRtg         60 non-null float64
# FT/FGA       60 non-null float64
# FT/FGA.1     60 non-null float64
# FTr          60 non-null float64
# L            60 non-null float64
# MOV          60 non-null float64
# NRtg         30 non-null float64
# ORB%         60 non-null float64
# ORtg         60 non-null float64
# PL           60 non-null float64
# PW           60 non-null float64
# Pace         60 non-null float64
# SOS          60 non-null float64
# SRS          60 non-null float64
# TOV%         60 non-null float64
# TOV%.1       60 non-null float64
# TS%          60 non-null float64
# Team         60 non-null object
# W            60 non-null float64
# eFG%         60 non-null float64
# eFG%.1       60 non-null float64
# FG_x         60 non-null float64
# FGA_x        60 non-null float64
# FG%_x        60 non-null float64
# 3P_x         60 non-null float64
# 3PA_x        60 non-null float64
# 3P%_x        60 non-null float64
# 2P_x         60 non-null float64
# 2PA_x        60 non-null float64
# 2P%_x        60 non-null float64
# FT_x         60 non-null float64
# FTA_x        60 non-null float64
# FT%_x        60 non-null float64
# ORB_x        60 non-null float64
# DRB_x        60 non-null float64
# TRB_x        60 non-null float64
# AST_x        60 non-null float64
# STL_x        60 non-null float64
# BLK_x        60 non-null float64
# TOV_x        60 non-null float64
# PF_x         60 non-null float64
# PTS_x        60 non-null float64
# FG_y         60 non-null float64
# FGA_y        60 non-null float64
# FG%_y        60 non-null float64
# 3P_y         60 non-null float64
# 3PA_y        60 non-null float64
# 3P%_y        60 non-null float64
# 2P_y         60 non-null float64
# 2PA_y        60 non-null float64
# 2P%_y        60 non-null float64
# FT_y         60 non-null float64
# FTA_y        60 non-null float64
# FT%_y        60 non-null float64
# ORB_y        60 non-null float64
# DRB_y        60 non-null float64
# TRB_y        60 non-null float64
# AST_y        60 non-null float64
# STL_y        60 non-null float64
# BLK_y        60 non-null float64
# TOV_y        60 non-null float64
# PF_y         60 non-null float64
# PTS_y        60 non-null float64
# dtypes: float64(66), int64(1), object(1)
# memory usage: 32.3+ KB
# None
# Building data set..
# 0 Cleveland Cavaliers*
# 1 Houston Rockets*
# 2 Milwaukee Bucks*
# 3 Atlanta Hawks*
# 4 Detroit Pistons*
# 5 Indiana Pacers*
# 6 Memphis Grizzlies*
# 7 Orlando Magic*
# 8 Portland Trail Blazers*
# 9 Houston Rockets*
# 10 San Antonio Spurs*
# 11 Utah Jazz*
# 12 Washington Wizards*
# 13 Los Angeles Clippers*
# 14 Oklahoma City Thunder*
# 15 Toronto Raptors*
# 16 Brooklyn Nets*
# 17 Charlotte Hornets*
# 18 Sacramento Kings*
# 19 Portland Trail Blazers*
# 20 Cleveland Cavaliers*
# 21 Minnesota Timberwolves*
# 22 Golden State Warriors*
# 23 Boston Celtics*
# 24 Los Angeles Lakers*
# 25 Washington Wizards*
# 26 San Antonio Spurs*
# 27 Orlando Magic*
# 28 Denver Nuggets*
# 29 Houston Rockets*
# 30 Los Angeles Clippers*
# 31 Memphis Grizzlies*
# 32 Miami Heat*
# 33 Milwaukee Bucks*
# 34 Detroit Pistons*
# 35 Toronto Raptors*
# 36 Utah Jazz*
# 37 Brooklyn Nets*
# 38 New Orleans Pelicans*
# 39 Minnesota Timberwolves*
# 40 Golden State Warriors*
# 41 Washington Wizards*
# 42 Philadelphia 76ers*
# 43 Memphis Grizzlies*
# 44 Miami Heat*
# 45 Milwaukee Bucks*
# 46 Phoenix Suns*
# 47 San Antonio Spurs*
# 48 Boston Celtics*
# 49 Cleveland Cavaliers*
# 50 Los Angeles Clippers*
# 51 Indiana Pacers*
# 52 Orlando Magic*
# 53 Portland Trail Blazers*
# 54 Brooklyn Nets*
# 55 Charlotte Hornets*
# 56 Dallas Mavericks*
# 57 Detroit Pistons*
# 58 Golden State Warriors*
# 59 Los Angeles Lakers*
# 60 San Antonio Spurs*
# 61 Oklahoma City Thunder*
# 62 Houston Rockets*
# 63 Phoenix Suns*
# 64 Chicago Bulls*
# 65 Memphis Grizzlies*
# 66 Boston Celtics*
# 67 Los Angeles Clippers*
# 68 New Orleans Pelicans*
# 69 Denver Nuggets*
# 70 Houston Rockets*
# 71 Golden State Warriors*
# 72 Toronto Raptors*
# 73 Minnesota Timberwolves*
# 74 New York Knicks*
# 75 Orlando Magic*
# 76 Oklahoma City Thunder*
# 77 Philadelphia 76ers*
# 78 Detroit Pistons*
# 79 Memphis Grizzlies*
# 80 Boston Celtics*
# 81 New Orleans Pelicans*
# 82 Portland Trail Blazers*
# 83 Utah Jazz*
# 84 Milwaukee Bucks*
# 85 Denver Nuggets*
# 86 Charlotte Hornets*
# 87 New York Knicks*
# 88 Detroit Pistons*
# 89 Indiana Pacers*
# 90 Washington Wizards*
# 91 Boston Celtics*
# 92 Philadelphia 76ers*
# 93 Golden State Warriors*
# 94 Charlotte Hornets*
# 95 Minnesota Timberwolves*
# 96 Orlando Magic*
# 97 New York Knicks*
# 98 Toronto Raptors*
# 99 Utah Jazz*
# 100 Phoenix Suns*
# 101 Indiana Pacers*
# 102 Los Angeles Lakers*
# 103 Oklahoma City Thunder*
# 104 Boston Celtics*
# 105 Charlotte Hornets*
# 106 Indiana Pacers*
# 107 Denver Nuggets*
# 108 Los Angeles Clippers*
# 109 Orlando Magic*
# 110 Miami Heat*
# 111 Minnesota Timberwolves*
# 112 Houston Rockets*
# 113 Philadelphia 76ers*
# 114 Utah Jazz*
# 115 Phoenix Suns*
# 116 Portland Trail Blazers*
# 117 Golden State Warriors*
# 118 Houston Rockets*
# 119 New Orleans Pelicans*
# 120 Denver Nuggets*
# 121 Detroit Pistons*
# 122 Los Angeles Lakers*
# 123 New York Knicks*
# 124 Boston Celtics*
# 125 Chicago Bulls*
# 126 Philadelphia 76ers*
# 127 San Antonio Spurs*
# 128 Toronto Raptors*
# 129 Cleveland Cavaliers*
# 130 New Orleans Pelicans*
# 131 Golden State Warriors*
# 132 Detroit Pistons*
# 133 Memphis Grizzlies*
# 134 Minnesota Timberwolves*
# 135 Atlanta Hawks*
# 136 Houston Rockets*
# 137 Miami Heat*
# 138 Los Angeles Lakers*
# 139 Minnesota Timberwolves*
# 140 New York Knicks*
# 141 Boston Celtics*
# 142 Portland Trail Blazers*
# 143 San Antonio Spurs*
# 144 Washington Wizards*
# 145 Boston Celtics*
# 146 Golden State Warriors*
# 147 Brooklyn Nets*
# 148 Cleveland Cavaliers*
# 149 Denver Nuggets*
# 150 New Orleans Pelicans*
# 151 New York Knicks*
# 152 Memphis Grizzlies*
# 153 Sacramento Kings*
# 154 San Antonio Spurs*
# 155 Toronto Raptors*
# 156 Philadelphia 76ers*
# 157 Dallas Mavericks*
# 158 Boston Celtics*
# 159 Detroit Pistons*
# 160 Golden State Warriors*
# 161 Orlando Magic*
# 162 Miami Heat*
# 163 Denver Nuggets*
# 164 Houston Rockets*
# 165 Sacramento Kings*
# 166 Toronto Raptors*
# 167 Washington Wizards*
# 168 Boston Celtics*
# 169 Indiana Pacers*
# 170 Detroit Pistons*
# 171 Oklahoma City Thunder*
# 172 Orlando Magic*
# 173 Brooklyn Nets*
# 174 Milwaukee Bucks*
# 175 Miami Heat*
# 176 Cleveland Cavaliers*
# 177 Denver Nuggets*
# 178 Golden State Warriors*
# 179 Houston Rockets*
# 180 Milwaukee Bucks*
# 181 New Orleans Pelicans*
# 182 New York Knicks*
# 183 Phoenix Suns*
# 184 San Antonio Spurs*
# 185 Utah Jazz*
# 186 Washington Wizards*
# 187 Boston Celtics*
# 188 Detroit Pistons*
# 189 Houston Rockets*
# 190 Oklahoma City Thunder*
# 191 Golden State Warriors*
# 192 Philadelphia 76ers*
# 193 Milwaukee Bucks*
# 194 New Orleans Pelicans*
# 195 Cleveland Cavaliers*
# 196 Los Angeles Lakers*
# 197 Portland Trail Blazers*
# 198 Minnesota Timberwolves*
# 199 Washington Wizards*
# 200 Boston Celtics*
# 201 San Antonio Spurs*
# 202 Toronto Raptors*
# 203 Atlanta Hawks*
# 204 Cleveland Cavaliers*
# 205 Philadelphia 76ers*
# 206 Indiana Pacers*
# 207 Washington Wizards*
# 208 Milwaukee Bucks*
# 209 Minnesota Timberwolves*
# 210 Toronto Raptors*
# 211 New York Knicks*
# 212 Oklahoma City Thunder*
# 213 Portland Trail Blazers*
# 214 Boston Celtics*
# 215 Houston Rockets*
# 216 Brooklyn Nets*
# 217 Chicago Bulls*
# 218 Cleveland Cavaliers*
# 219 Minnesota Timberwolves*
# 220 Denver Nuggets*
# 221 Indiana Pacers*
# 222 Phoenix Suns*
# 223 Sacramento Kings*
# 224 San Antonio Spurs*
# 225 Toronto Raptors*
# 226 Miami Heat*
# 227 Boston Celtics*
# 228 Charlotte Hornets*
# 229 Dallas Mavericks*
# 230 Houston Rockets*
# 231 Utah Jazz*
# 232 Golden State Warriors*
# 233 Portland Trail Blazers*
# 234 Golden State Warriors*
# 235 Los Angeles Lakers*
# 236 Indiana Pacers*
# 237 Detroit Pistons*
# 238 Phoenix Suns*
# 239 Toronto Raptors*
# 240 Charlotte Hornets*
# 241 Boston Celtics*
# 242 Cleveland Cavaliers*
# 243 Portland Trail Blazers*
# 244 Washington Wizards*
# 245 New Orleans Pelicans*
# 246 New York Knicks*
# 247 Indiana Pacers*
# 248 Philadelphia 76ers*
# 249 Denver Nuggets*
# 250 San Antonio Spurs*
# 251 Los Angeles Lakers*
# 252 Los Angeles Clippers*
# 253 Charlotte Hornets*
# 254 Cleveland Cavaliers*
# 255 Houston Rockets*
# 256 Dallas Mavericks*
# 257 Miami Heat*
# 258 Minnesota Timberwolves*
# 259 New Orleans Pelicans*
# 260 New York Knicks*
# 261 Oklahoma City Thunder*
# 262 Philadelphia 76ers*
# 263 Milwaukee Bucks*
# 264 Sacramento Kings*
# 265 Utah Jazz*
# 266 Atlanta Hawks*
# 267 Boston Celtics*
# 268 Portland Trail Blazers*
# 269 Cleveland Cavaliers*
# 270 Denver Nuggets*
# 271 Golden State Warriors*
# 272 Indiana Pacers*
# 273 Miami Heat*
# 274 Detroit Pistons*
# 275 New Orleans Pelicans*
# 276 Toronto Raptors*
# 277 San Antonio Spurs*
# 278 Dallas Mavericks*
# 279 Golden State Warriors*
# 280 Houston Rockets*
# 281 Boston Celtics*
# 282 Philadelphia 76ers*
# 283 Los Angeles Clippers*
# 284 Utah Jazz*
# 285 Portland Trail Blazers*
# 286 Miami Heat*
# 287 Brooklyn Nets*
# 288 Minnesota Timberwolves*
# 289 Detroit Pistons*
# 290 Sacramento Kings*
# 291 Houston Rockets*
# 292 Indiana Pacers*
# 293 Los Angeles Clippers*
# 294 Portland Trail Blazers*
# 295 Cleveland Cavaliers*
# 296 San Antonio Spurs*
# 297 Phoenix Suns*
# 298 Cleveland Cavaliers*
# 299 Washington Wizards*
# 300 Milwaukee Bucks*
# 301 Utah Jazz*
# 302 Brooklyn Nets*
# 303 Detroit Pistons*
# 304 Houston Rockets*
# 305 Golden State Warriors*
# 306 Minnesota Timberwolves*
# 307 New York Knicks*
# 308 Orlando Magic*
# 309 Philadelphia 76ers*
# 310 San Antonio Spurs*
# 311 Toronto Raptors*
# 312 Cleveland Cavaliers*
# 313 Boston Celtics*
# 314 Denver Nuggets*
# 315 Utah Jazz*
# 316 Milwaukee Bucks*
# 317 Sacramento Kings*
# 318 San Antonio Spurs*
# 319 Miami Heat*
# 320 Oklahoma City Thunder*
# 321 Golden State Warriors*
# 322 Toronto Raptors*
# 323 Utah Jazz*
# 324 Washington Wizards*
# 325 Boston Celtics*
# 326 Atlanta Hawks*
# 327 Cleveland Cavaliers*
# 328 Dallas Mavericks*
# 329 Denver Nuggets*
# 330 Milwaukee Bucks*
# 331 Philadelphia 76ers*
# 332 New Orleans Pelicans*
# 333 Houston Rockets*
# 334 Golden State Warriors*
# 335 Minnesota Timberwolves*
# 336 Orlando Magic*
# 337 Oklahoma City Thunder*
# 338 Brooklyn Nets*
# 339 Boston Celtics*
# 340 Cleveland Cavaliers*
# 341 Charlotte Hornets*
# 342 Dallas Mavericks*
# 343 Indiana Pacers*
# 344 Memphis Grizzlies*
# 345 Golden State Warriors*
# 346 Phoenix Suns*
# 347 San Antonio Spurs*
# 348 Utah Jazz*
# 349 Oklahoma City Thunder*
# 350 Washington Wizards*
# 351 Toronto Raptors*
# 352 Boston Celtics*
# 353 Golden State Warriors*
# 354 Cleveland Cavaliers*
# 355 Indiana Pacers*
# 356 Minnesota Timberwolves*
# 357 Milwaukee Bucks*
# 358 New Orleans Pelicans*
# 359 New York Knicks*
# 360 Orlando Magic*
# 361 San Antonio Spurs*
# 362 Brooklyn Nets*
# 363 Los Angeles Lakers*
# 364 Washington Wizards*
# 365 Houston Rockets*
# 366 Chicago Bulls*
# 367 Golden State Warriors*
# 368 Indiana Pacers*
# 369 Toronto Raptors*
# 370 Milwaukee Bucks*
# 371 Sacramento Kings*
# 372 Denver Nuggets*
# 373 San Antonio Spurs*
# 374 Atlanta Hawks*
# 375 Miami Heat*
# 376 Chicago Bulls*
# 377 Los Angeles Lakers*
# 378 Cleveland Cavaliers*
# 379 Los Angeles Clippers*
# 380 Oklahoma City Thunder*
# 381 Milwaukee Bucks*
# 382 San Antonio Spurs*
# 383 Houston Rockets*
# 384 Boston Celtics*
# 385 Indiana Pacers*
# 386 Minnesota Timberwolves*
# 387 New Orleans Pelicans*
# 388 New York Knicks*
# 389 Toronto Raptors*
# 390 Chicago Bulls*
# 391 Golden State Warriors*
# 392 Houston Rockets*
# 393 Los Angeles Clippers*
# 394 Miami Heat*
# 395 Charlotte Hornets*
# 396 Brooklyn Nets*
# 397 Cleveland Cavaliers*
# 398 Dallas Mavericks*
# 399 Denver Nuggets*
# 400 Philadelphia 76ers*
# 401 New York Knicks*
# 402 Sacramento Kings*
# 403 Boston Celtics*
# 404 Chicago Bulls*
# 405 Houston Rockets*
# 406 Oklahoma City Thunder*
# 407 Portland Trail Blazers*
# 408 New Orleans Pelicans*
# 409 Los Angeles Clippers*
# 410 Toronto Raptors*
# 411 Washington Wizards*
# 412 Detroit Pistons*
# 413 New York Knicks*
# 414 Cleveland Cavaliers*
# 415 Golden State Warriors*
# 416 Minnesota Timberwolves*
# 417 Utah Jazz*
# 418 Miami Heat*
# 419 Denver Nuggets*
# 420 Houston Rockets*
# 421 Detroit Pistons*
# 422 Memphis Grizzlies*
# 423 Chicago Bulls*
# 424 Portland Trail Blazers*
# 425 Oklahoma City Thunder*
# 426 Toronto Raptors*
# 427 Washington Wizards*
# 428 Portland Trail Blazers*
# 429 Cleveland Cavaliers*
# 430 Houston Rockets*
# 431 Boston Celtics*
# 432 Miami Heat*
# 433 Phoenix Suns*
# 434 New York Knicks*
# 435 San Antonio Spurs*
# 436 Indiana Pacers*
# 437 Detroit Pistons*
# 438 Toronto Raptors*
# 439 Cleveland Cavaliers*
# 440 Atlanta Hawks*
# 441 Chicago Bulls*
# 442 Charlotte Hornets*
# 443 Phoenix Suns*
# 444 Houston Rockets*
# 445 Boston Celtics*
# 446 Golden State Warriors*
# 447 Minnesota Timberwolves*
# 448 Oklahoma City Thunder*
# 449 San Antonio Spurs*
# 450 Milwaukee Bucks*
# 451 Sacramento Kings*
# 452 Washington Wizards*
# 453 Indiana Pacers*
# 454 Miami Heat*
# 455 Sacramento Kings*
# 456 Chicago Bulls*
# 457 Toronto Raptors*
# 458 Dallas Mavericks*
# 459 Minnesota Timberwolves*
# 460 Golden State Warriors*
# 461 Los Angeles Lakers*
# 462 Los Angeles Clippers*
# 463 Oklahoma City Thunder*
# 464 San Antonio Spurs*
# 569 Denver Nuggets*
# 570 Charlotte Hornets*
# 571 Washington Wizards*
# 572 Miami Heat*
# 573 Toronto Raptors*
# 574 Philadelphia 76ers*
# 575 Portland Trail Blazers*
# 576 San Antonio Spurs*
# 577 Boston Celtics*
# 578 Detroit Pistons*
# 579 Indiana Pacers*
# 580 Golden State Warriors*
# 581 Minnesota Timberwolves*
# 582 Cleveland Cavaliers*
# 583 Sacramento Kings*
# 584 Milwaukee Bucks*
# 585 New York Knicks*
# 586 Los Angeles Lakers*
# 587 Miami Heat*
# 588 Phoenix Suns*
# 589 Portland Trail Blazers*
# 590 Toronto Raptors*
# 591 Houston Rockets*
# 592 Golden State Warriors*
# 593 Indiana Pacers*
# 594 Los Angeles Clippers*
# 595 Minnesota Timberwolves*
# 596 New Orleans Pelicans*
# 597 San Antonio Spurs*
# 598 Dallas Mavericks*
# 599 Los Angeles Lakers*
# 600 Portland Trail Blazers*
# 601 Miami Heat*
# 602 Detroit Pistons*
# 603 Dallas Mavericks*
# 604 Atlanta Hawks*
# 605 Los Angeles Clippers*
# 606 Houston Rockets*
# 607 Miami Heat*
# 608 Memphis Grizzlies*
# 609 Milwaukee Bucks*
# 610 Minnesota Timberwolves*
# 611 Chicago Bulls*
# 612 Utah Jazz*
# 613 Los Angeles Lakers*
# 614 Boston Celtics*
# 615 Los Angeles Clippers*
# 616 Toronto Raptors*
# 617 Brooklyn Nets*
# 618 Charlotte Hornets*
# 619 Denver Nuggets*
# 620 Indiana Pacers*
# 621 Golden State Warriors*
# 622 Minnesota Timberwolves*
# 623 New Orleans Pelicans*
# 624 Houston Rockets*
# 625 Washington Wizards*
# 626 Chicago Bulls*
# 627 Oklahoma City Thunder*
# 628 Los Angeles Lakers*
# 629 Los Angeles Clippers*
# 630 San Antonio Spurs*
# 631 Golden State Warriors*
# 632 Washington Wizards*
# 633 Miami Heat*
# 634 Minnesota Timberwolves*
# 635 New Orleans Pelicans*
# 636 Indiana Pacers*
# 637 Atlanta Hawks*
# 638 New York Knicks*
# 639 Chicago Bulls*
# 640 Golden State Warriors*
# 641 Charlotte Hornets*
# 642 Los Angeles Clippers*
# 643 Memphis Grizzlies*
# 644 Oklahoma City Thunder*
# 645 Philadelphia 76ers*
# 646 Indiana Pacers*
# 647 Milwaukee Bucks*
# 648 New Orleans Pelicans*
# 649 Denver Nuggets*
# 650 Orlando Magic*
# 651 Portland Trail Blazers*
# 652 Atlanta Hawks*
# 653 San Antonio Spurs*
# 654 Golden State Warriors*
# 655 Charlotte Hornets*
# 656 Los Angeles Clippers*
# 657 Memphis Grizzlies*
# 658 Miami Heat*
# 659 Oklahoma City Thunder*
# 660 Utah Jazz*
# 661 Toronto Raptors*
# 662 Philadelphia 76ers*
# 663 Cleveland Cavaliers*
# 664 Houston Rockets*
# 665 Portland Trail Blazers*
# 666 Brooklyn Nets*
# 667 Phoenix Suns*
# 668 Washington Wizards*
# 669 Los Angeles Lakers*
# 670 Memphis Grizzlies*
# 671 Toronto Raptors*
# 672 New York Knicks*
# 673 Chicago Bulls*
# 674 Miami Heat*
# 675 Oklahoma City Thunder*
# 676 Houston Rockets*
# 677 Minnesota Timberwolves*
# 678 New Orleans Pelicans*
# 679 Philadelphia 76ers*
# 680 Portland Trail Blazers*
# 681 Utah Jazz*
# 682 Orlando Magic*
# 683 Brooklyn Nets*
# 684 Los Angeles Lakers*
# 685 Indiana Pacers*
# 686 Atlanta Hawks*
# 687 Charlotte Hornets*
# 688 Dallas Mavericks*
# 689 Denver Nuggets*
# 690 Houston Rockets*
# 691 Minnesota Timberwolves*
# 692 Memphis Grizzlies*
# 693 Milwaukee Bucks*
# 694 New Orleans Pelicans*
# 695 Golden State Warriors*
# 696 Los Angeles Lakers*
# 697 Oklahoma City Thunder*
# 698 Sacramento Kings*
# 699 San Antonio Spurs*
# 700 Toronto Raptors*
# 701 New Orleans Pelicans*
# 702 Houston Rockets*
# 703 Utah Jazz*
# 704 Indiana Pacers*
# 705 Boston Celtics*
# 706 San Antonio Spurs*
# 707 Philadelphia 76ers*
# 708 Portland Trail Blazers*
# 709 Denver Nuggets*
# 710 Golden State Warriors*
# 711 Sacramento Kings*
# 712 Oklahoma City Thunder*
# 713 Los Angeles Lakers*
# 714 Charlotte Hornets*
# 715 Cleveland Cavaliers*
# 716 Portland Trail Blazers*
# 717 Los Angeles Clippers*
# 718 Milwaukee Bucks*
# 719 New Orleans Pelicans*
# 720 New York Knicks*
# 721 Philadelphia 76ers*
# 722 Utah Jazz*
# 723 Washington Wizards*
# 724 Denver Nuggets*
# 725 Oklahoma City Thunder*
# 726 Golden State Warriors*
# 727 Indiana Pacers*
# 728 Miami Heat*
# 729 Minnesota Timberwolves*
# 730 Milwaukee Bucks*
# 731 Cleveland Cavaliers*
# 732 Houston Rockets*
# 733 Los Angeles Clippers*
# 734 Oklahoma City Thunder*
# 735 San Antonio Spurs*
# 736 Toronto Raptors*
# 737 Atlanta Hawks*
# 738 Miami Heat*
# 739 Boston Celtics*
# 740 Indiana Pacers*
# 741 Memphis Grizzlies*
# 742 Milwaukee Bucks*
# 743 Detroit Pistons*
# 744 Houston Rockets*
# 745 Portland Trail Blazers*
# 746 Sacramento Kings*
# 747 New York Knicks*
# 748 San Antonio Spurs*
# 749 Toronto Raptors*
# 750 Utah Jazz*
# 751 Washington Wizards*
# 752 Charlotte Hornets*
# 753 Boston Celtics*
# 754 Brooklyn Nets*
# 755 Cleveland Cavaliers*
# 756 Indiana Pacers*
# 757 Orlando Magic*
# 758 Phoenix Suns*
# 759 Portland Trail Blazers*
# 760 Denver Nuggets*
# 761 Detroit Pistons*
# 762 Minnesota Timberwolves*
# 763 Houston Rockets*
# 764 Washington Wizards*
# 765 Boston Celtics*
# 766 Los Angeles Lakers*
# 767 Charlotte Hornets*
# 768 Milwaukee Bucks*
# 769 New Orleans Pelicans*
# 770 Philadelphia 76ers*
# 771 Utah Jazz*
# 772 Golden State Warriors*
# 773 Toronto Raptors*
# 774 Houston Rockets*
# 775 Denver Nuggets*
# 776 Detroit Pistons*
# 777 Indiana Pacers*
# 778 Los Angeles Clippers*
# 779 Minnesota Timberwolves*
# 780 Washington Wizards*
# 781 Dallas Mavericks*
# 782 Utah Jazz*
# 783 Boston Celtics*
# 784 Milwaukee Bucks*
# 785 Atlanta Hawks*
# 786 Los Angeles Lakers*
# 787 Charlotte Hornets*
# 788 Toronto Raptors*
# 789 Denver Nuggets*
# 790 Detroit Pistons*
# 791 Washington Wizards*
# 792 Los Angeles Clippers*
# 793 Orlando Magic*
# 794 Utah Jazz*
# 795 Sacramento Kings*
# 796 Atlanta Hawks*
# 797 Houston Rockets*
# 798 Oklahoma City Thunder*
# 799 Los Angeles Lakers*
# 800 Milwaukee Bucks*
# 801 Orlando Magic*
# 802 Philadelphia 76ers*
# 803 Toronto Raptors*
# 804 Cleveland Cavaliers*
# 805 Detroit Pistons*
# 806 Utah Jazz*
# 807 Houston Rockets*
# 808 San Antonio Spurs*
# 809 Golden State Warriors*
# 810 Los Angeles Lakers*
# 811 Orlando Magic*
# 812 Portland Trail Blazers*
# 813 Toronto Raptors*
# 814 Boston Celtics*
# 815 Cleveland Cavaliers*
# 816 Indiana Pacers*
# 817 Chicago Bulls*
# 818 Los Angeles Clippers*
# 819 Houston Rockets*
# 820 Miami Heat*
# 821 Philadelphia 76ers*
# 822 Portland Trail Blazers*
# 823 Utah Jazz*
# 824 New Orleans Pelicans*
# 825 Washington Wizards*
# 826 Dallas Mavericks*
# 827 Golden State Warriors*
# 828 Milwaukee Bucks*
# 829 Philadelphia 76ers*
# 830 Denver Nuggets*
# 831 Atlanta Hawks*
# 832 Cleveland Cavaliers*
# 833 Toronto Raptors*
# 834 Houston Rockets*
# 835 Indiana Pacers*
# 836 Minnesota Timberwolves*
# 837 Oklahoma City Thunder*
# 838 Utah Jazz*
# 839 Los Angeles Clippers*
# 840 Chicago Bulls*
# 841 New Orleans Pelicans*
# 842 Golden State Warriors*
# 843 Philadelphia 76ers*
# 844 Utah Jazz*
# 845 Sacramento Kings*
# 846 Denver Nuggets*
# 847 Milwaukee Bucks*
# 848 Houston Rockets*
# 849 Cleveland Cavaliers*
# 850 Toronto Raptors*
# 851 Los Angeles Clippers*
# 852 Indiana Pacers*
# 853 Toronto Raptors*
# 854 Detroit Pistons*
# 855 Houston Rockets*
# 856 Oklahoma City Thunder*
# 857 New Orleans Pelicans*
# 858 Washington Wizards*
# 859 Charlotte Hornets*
# 860 Philadelphia 76ers*
# 861 Portland Trail Blazers*
# 862 Utah Jazz*
# 863 Denver Nuggets*
# 864 Minnesota Timberwolves*
# 865 Philadelphia 76ers*
# 866 Charlotte Hornets*
# 867 Washington Wizards*
# 868 Golden State Warriors*
# 869 New York Knicks*
# 870 Oklahoma City Thunder*
# 871 Denver Nuggets*
# 872 Boston Celtics*
# 873 Houston Rockets*
# 874 Indiana Pacers*
# 875 Los Angeles Lakers*
# 876 Cleveland Cavaliers*
# 877 New Orleans Pelicans*
# 878 Los Angeles Clippers*
# 879 Milwaukee Bucks*
# 880 Portland Trail Blazers*
# 881 Charlotte Hornets*
# 882 Golden State Warriors*
# 883 Miami Heat*
# 884 Minnesota Timberwolves*
# 885 Boston Celtics*
# 886 Philadelphia 76ers*
# 887 Portland Trail Blazers*
# 888 Los Angeles Lakers*
# 889 Utah Jazz*
# 890 Charlotte Hornets*
# 891 San Antonio Spurs*
# 892 Houston Rockets*
# 893 New Orleans Pelicans*
# 894 Washington Wizards*
# 895 Los Angeles Lakers*
# 896 Boston Celtics*
# 897 Brooklyn Nets*
# 898 Dallas Mavericks*
# 899 New Orleans Pelicans*
# 900 Golden State Warriors*
# 901 Oklahoma City Thunder*
# 902 Minnesota Timberwolves*
# 903 Toronto Raptors*
# 904 Houston Rockets*
# 905 Charlotte Hornets*
# 906 Cleveland Cavaliers*
# 907 Los Angeles Clippers*
# 908 Miami Heat*
# 909 Washington Wizards*
# 910 Portland Trail Blazers*
# 911 Atlanta Hawks*
# 912 Boston Celtics*
# 913 Oklahoma City Thunder*
# 914 Detroit Pistons*
# 915 Houston Rockets*
# 916 Phoenix Suns*
# 917 Toronto Raptors*
# 918 New Orleans Pelicans*
# 919 Golden State Warriors*
# 920 Philadelphia 76ers*
# 921 Los Angeles Lakers*
# 922 Portland Trail Blazers*
# 923 Sacramento Kings*
# 924 Golden State Warriors*
# 925 Chicago Bulls*
# 926 Los Angeles Clippers*
# 927 Denver Nuggets*
# 928 Indiana Pacers*
# 929 Orlando Magic*
# 930 Philadelphia 76ers*
# 931 Oklahoma City Thunder*
# 932 Utah Jazz*
# 933 Toronto Raptors*
# 934 Denver Nuggets*
# 935 Houston Rockets*
# 936 Miami Heat*
# 937 Orlando Magic*
# 938 Portland Trail Blazers*
# 939 Utah Jazz*
# 940 Los Angeles Lakers*
# 941 Atlanta Hawks*
# 942 New Orleans Pelicans*
# 943 Los Angeles Clippers*
# 944 Milwaukee Bucks*
# 945 Sacramento Kings*
# 946 Toronto Raptors*
# 947 Indiana Pacers*
# 948 Boston Celtics*
# 949 Cleveland Cavaliers*
# 950 Indiana Pacers*
# 951 Portland Trail Blazers*
# 952 Miami Heat*
# 953 San Antonio Spurs*
# 954 Utah Jazz*
# 955 Philadelphia 76ers*
# 956 Dallas Mavericks*
# 957 Golden State Warriors*
# 958 New Orleans Pelicans*
# 959 Houston Rockets*
# 960 Portland Trail Blazers*
# 961 Toronto Raptors*
# 962 Washington Wizards*
# 963 Chicago Bulls*
# 964 Cleveland Cavaliers*
# 965 Toronto Raptors*
# 966 Utah Jazz*
# 967 Los Angeles Lakers*
# 968 Houston Rockets*
# 969 New Orleans Pelicans*
# 970 Brooklyn Nets*
# 971 Golden State Warriors*
# 972 Miami Heat*
# 973 Boston Celtics*
# 974 Oklahoma City Thunder*
# 975 Denver Nuggets*
# 976 Detroit Pistons*
# 977 Indiana Pacers*
# 978 Los Angeles Clippers*
# 979 Utah Jazz*
# 980 Milwaukee Bucks*
# 981 Washington Wizards*
# 982 Portland Trail Blazers*
# 983 Sacramento Kings*
# 984 Toronto Raptors*
# 1489 Milwaukee Bucks
# 1490 Denver Nuggets
# 1491 Philadelphia 76ers
# 1492 Memphis Grizzlies
# 1493 Sacramento Kings
# 1494 Boston Celtics
# 1495 Minnesota Timberwolves
# 1496 Miami Heat
# 1497 Denver Nuggets
# 1498 Detroit Pistons
# 1499 Golden State Warriors
# 1500 San Antonio Spurs
# 1501 Los Angeles Clippers
# 1502 Los Angeles Lakers
# 1503 Phoenix Suns
# 1504 New York Knicks
# 1505 Oklahoma City Thunder
# 1506 Cleveland Cavaliers
# 1507 Toronto Raptors
# 1508 Cleveland Cavaliers
# 1509 Dallas Mavericks
# 1510 Golden State Warriors
# 1511 Milwaukee Bucks
# 1512 Minnesota Timberwolves
# 1513 Denver Nuggets
# 1514 Washington Wizards
# 1515 Atlanta Hawks
# 1516 Philadelphia 76ers
# 1517 Detroit Pistons
# 1518 Orlando Magic
# 1519 New York Knicks
# 1520 Los Angeles Clippers
# 1521 Utah Jazz
# 1522 Toronto Raptors
# 1523 San Antonio Spurs
# 1524 Charlotte Hornets
# 1525 Minnesota Timberwolves
# 1526 Golden State Warriors
# 1527 Boston Celtics
# 1528 Indiana Pacers
# 1529 Washington Wizards
# 1530 Denver Nuggets
# 1531 Detroit Pistons
# 1532 Toronto Raptors
# 1533 Atlanta Hawks
# 1534 Indiana Pacers
# 1535 Utah Jazz
# 1536 Charlotte Hornets
# 1537 Dallas Mavericks
# 1538 Los Angeles Clippers
# 1539 Milwaukee Bucks
# 1540 Minnesota Timberwolves
# 1541 New Orleans Pelicans
# 1542 Oklahoma City Thunder
# 1543 Philadelphia 76ers
# 1544 Portland Trail Blazers
# 1545 Los Angeles Lakers
# 1546 Los Angeles Clippers
# 1547 Toronto Raptors
# 1548 Boston Celtics
# 1549 Memphis Grizzlies
# 1550 Utah Jazz
# 1551 Detroit Pistons
# 1552 Los Angeles Lakers
# 1553 Miami Heat
# 1554 Oklahoma City Thunder
# 1555 Philadelphia 76ers
# 1556 Orlando Magic
# 1557 Denver Nuggets
# 1558 Houston Rockets
# Fitting on 1559 game samples..
# Doing cross-validation..
# 0.6715224984590097
# Predicting on new schedule..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-4099766bfbb7> in <module>()
#      36         team1 = row['VTeam']
#      37         team2 = row['HTeam']
# ---> 38         pred = predict_winner(team1, team2, model)
#      39         prob = pred[0][0]
#      40         if prob > 0.5:
#
# <ipython-input-59-c93dd85783ef> in predict_winner(team_1, team_2, model)
#      91     # team 1，visitor team
#      92     features.append(get_elo(team_1))
# ---> 93     for key, value in team_stats.loc[team_1].iteritems():
#      94         features.append(value)
#      95
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1432                 key = self._convert_scalar_indexer(key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#    1436
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1424             def error():
#    1425                 if isnull(key):
# -> 1426                     raise TypeError("cannot use label indexing with a null "
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
#
# TypeError: cannot use label indexing with a null key
