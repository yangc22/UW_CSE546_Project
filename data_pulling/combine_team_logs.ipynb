# %%
import pandas as pd

# %%
def combine_season_games(season1, season2):
    stats_folder = ''
    file_name = 'season_games'
    file_type = '.xlsx'
    df1 = pd.read_excel("{}{}_{}{}".format(stats_folder, season1, file_name, file_type))
    df1 = df1[df1['schedule.playedStatus'] == 'COMPLETED']
    df2 = pd.read_excel("{}{}_{}{}".format(stats_folder, season2, file_name, file_type))
    df2 = df2[df2['schedule.playedStatus'] == 'COMPLETED']
    df = df1.append(df2, ignore_index=True)
    dropped = ['schedule.attendance', 'schedule.broadcasters', 'schedule.delayedOrPostponedReason', 'schedule.endedTime', 'schedule.officials', 'schedule.originalStartTime', 'schedule.weather', 'score.currentIntermission', 'score.currentQuarter', 'score.currentQuarterSecondsRemaining', 'score.quarters']
    df = df[df.columns.drop(dropped)]
    output_folder = ''
    output_format = 'csv'
    # save the df
    # df.to_csv("{}{}_{}.{}".format(output_folder, 'combined', file_name, output_format), encoding='utf-8', index=False)
    # return the df for debugging
    return df

# %%
# 17-18 season 1229 games
# 18-19 season 378 games already finished
df = combine_season_games('1718', '1819')
# 2018-11-16T01:00:00.000Z
# 2018-12-01T00:00:00.000Z
df[(df['schedule.startTime'] >= '2018-11-16T01:00:00.000Z') & (df['schedule.startTime'] < '2018-12-01T00:00:00.000Z')]
# df[df['schedule.startTime'] > df.loc[1600]['schedule.startTime']]
# Out:
#      schedule.awayTeam.abbreviation  schedule.awayTeam.id  \
# 1442                            GSW                   101
# 1443                            ATL                    91
# 1444                            SAS                   106
# 1445                            TOR                    81
# 1446                            MIA                    92
# 1447                            UTA                    98
# 1448                            BRO                    84
# 1449                            SAC                   103
# 1450                            POR                    97
# 1451                            NYK                    83
# 1452                            CHI                    89
# 1453                            LAC                   102
# 1454                            PHI                    85
# 1455                            ATL                    91
# 1456                            LAL                   105
# 1457                            DEN                    99
# 1458                            UTA                    98
# 1459                            TOR                    81
# 1460                            SAC                   103
# 1461                            GSW                   101
# 1462                            OKL                    96
# 1463                            MEM                   107
# 1464                            LAL                   105
# 1465                            NYK                    83
# 1466                            POR                    97
# 1467                            GSW                   101
# 1468                            BOS                    82
# 1469                            CLE                    86
# 1470                            UTA                    98
# 1471                            PHX                   104
# ...                             ...                   ...
# 1518                            PHI                    85
# 1519                            MIA                    92
# 1520                            NYK                    83
# 1521                            UTA                    98
# 1522                            LAC                   102
# 1523                            MIL                    90
# 1524                            MIN                   100
# 1525                            HOU                   109
# 1526                            SAS                   106
# 1527                            BOS                    82
# 1528                            IND                    87
# 1529                            ORL                    95
# 1530                            NYK                    83
# 1531                            ATL                    91
# 1532                            TOR                    81
# 1533                            LAL                   105
# 1534                            IND                    87
# 1535                            ATL                    91
# 1536                            NYK                    83
# 1537                            UTA                    98
# 1538                            DAL                   108
# 1539                            CHI                    89
# 1540                            SAS                   106
# 1541                            WAS                    94
# 1542                            CLE                    86
# 1543                            ORL                    95
# 1544                            PHX                   104
# 1545                            GSW                   101
# 1546                            IND                    87
# 1547                            LAC                   102
#
#      schedule.homeTeam.abbreviation  schedule.homeTeam.id  schedule.id  \
# 1442                            HOU                   109        47782
# 1443                            DEN                    99        47783
# 1444                            LAC                   102        47784
# 1445                            BOS                    82        47785
# 1446                            IND                    87        47786
# 1447                            PHI                    85        47787
# 1448                            WAS                    94        47788
# 1449                            MEM                   107        47789
# 1450                            MIN                   100        47790
# 1451                            NOP                   110        47791
# 1452                            MIL                    90        47792
# 1453                            BRO                    84        47793
# 1454                            CHA                    93        47794
# 1455                            IND                    87        47795
# 1456                            ORL                    95        47796
# 1457                            NOP                   110        47797
# 1458                            BOS                    82        47798
# 1459                            CHI                    89        47799
# 1460                            HOU                   109        47800
# 1461                            DAL                   108        47801
# 1462                            PHX                   104        47802
# 1463                            MIN                   100        47803
# 1464                            MIA                    92        47804
# 1465                            ORL                    95        47805
# 1466                            WAS                    94        47806
# 1467                            SAS                   106        47807
# 1468                            CHA                    93        47808
# 1469                            DET                    88        47809
# 1470                            IND                    87        47810
# 1471                            PHI                    85        47811
# ...                             ...                   ...          ...
# 1518                            BRO                    84        47858
# 1519                            TOR                    81        47859
# 1520                            MEM                   107        47860
# 1521                            SAC                   103        47861
# 1522                            POR                    97        47862
# 1523                            CHA                    93        47863
# 1524                            CLE                    86        47864
# 1525                            WAS                    94        47865
# 1526                            CHI                    89        47866
# 1527                            NOP                   110        47867
# 1528                            UTA                    98        47868
# 1529                            GSW                   101        47869
# 1530                            DET                    88        47870
# 1531                            MIA                    92        47871
# 1532                            MEM                   107        47872
# 1533                            DEN                    99        47873
# 1534                            PHX                   104        47874
# 1535                            CHA                    93        47875
# 1536                            PHI                    85        47876
# 1537                            BRO                    84        47877
# 1538                            HOU                   109        47878
# 1539                            MIL                    90        47879
# 1540                            MIN                   100        47880
# 1541                            NOP                   110        47881
# 1542                            OKL                    96        47882
# 1543                            POR                    97        47883
# 1544                            LAC                   102        47884
# 1545                            TOR                    81        47885
# 1546                            LAL                   105        47886
# 1547                            SAC                   103        47887
#
#      schedule.playedStatus schedule.scheduleStatus        schedule.startTime  \
# 1442             COMPLETED                  NORMAL  2018-11-16T01:00:00.000Z
# 1443             COMPLETED                  NORMAL  2018-11-16T02:00:00.000Z
# 1444             COMPLETED                  NORMAL  2018-11-16T03:30:00.000Z
# 1445             COMPLETED                  NORMAL  2018-11-17T00:00:00.000Z
# 1446             COMPLETED                  NORMAL  2018-11-17T00:00:00.000Z
# 1447             COMPLETED                  NORMAL  2018-11-17T00:00:00.000Z
# 1448             COMPLETED                  NORMAL  2018-11-17T00:00:00.000Z
# 1449             COMPLETED                  NORMAL  2018-11-17T01:00:00.000Z
# 1450             COMPLETED                  NORMAL  2018-11-17T01:00:00.000Z
# 1451             COMPLETED                  NORMAL  2018-11-17T01:00:00.000Z
# 1452             COMPLETED                  NORMAL  2018-11-17T02:30:00.000Z
# 1453             COMPLETED                  NORMAL  2018-11-17T23:00:00.000Z
# 1454             COMPLETED                  NORMAL  2018-11-18T00:00:00.000Z
# 1455             COMPLETED                  NORMAL  2018-11-18T00:00:00.000Z
# 1456             COMPLETED                  NORMAL  2018-11-18T00:00:00.000Z
# 1457             COMPLETED                  NORMAL  2018-11-18T00:00:00.000Z
# 1458             COMPLETED                  NORMAL  2018-11-18T00:30:00.000Z
# 1455                  89.0                  97.0
# 1456                 117.0                 130.0
# 1457                 115.0                 125.0
# 1458                  98.0                  86.0
# 1459                 122.0                  83.0
# 1460                 112.0                 132.0
# 1461                 109.0                 112.0
# 1462                 110.0                 100.0
# 1463                 100.0                  87.0
# 1464                 113.0                  97.0
# 1465                 117.0                 131.0
# 1466                 119.0                 109.0
# 1467                  92.0                 104.0
# 1468                 112.0                 117.0
# 1469                 102.0                 113.0
# 1470                  94.0                 121.0
# 1471                 114.0                 119.0
# ...                    ...                   ...
# 1518                 127.0                 125.0
# 1519                 115.0                 125.0
# 1520                 103.0                  98.0
# 1521                 133.0                 112.0
# 1522                 104.0                 100.0
# 1523                 107.0                 110.0
# 1524                 102.0                  95.0
# 1525                 131.0                 135.0
# 1526                 108.0                 107.0
# 1527                 124.0                 107.0
# 1528                 121.0                  88.0
# 1529                 110.0                 116.0
# 1530                 108.0                 115.0
# 1531                 115.0                 113.0
# 1532                 122.0                 114.0
# 1533                  85.0                 117.0
# 1534                 109.0                 104.0
# 1535                  94.0                 108.0
# 1536                  91.0                 117.0
# 1537                 101.0                  91.0
# 1538                 128.0                 108.0
# 1539                 113.0                 116.0
# 1540                  89.0                 128.0
# 1541                 104.0                 125.0
# 1542                  83.0                 100.0
# 1543                 112.0                 115.0
# 1544                  99.0                 115.0
# 1545                 128.0                 131.0
# 1546                  96.0                 104.0
# 1547                 133.0                 121.0
#
# [106 rows x 13 columns]

# %%
stats_folder = 'team_game_logs_'
file_name = 'team_game_log'
season1 = '1718'
season2 = '1819'
team_name = 'ATL'
file_type = '.xlsx'
df1 = pd.read_excel("{}{}/{}_{}{}".format(stats_folder, season1, file_name, team_name, file_type))
df2 = pd.read_excel("{}{}/{}_{}{}".format(stats_folder, season2, file_name, team_name, file_type))

# %%
df_ATL = df1.append(df2, ignore_index=True)
df_ATL[(df_ATL['game.awayTeamAbbreviation'] == 'ATL') & (df_ATL['game.id'] == 47783)]
# df_ATL[df_ATL['game.startTime'] < '2018-11-16T02:00:00.000Z'].tail(5)
# df_ATL[df_ATL['game.startTime'] < df.loc[1443]['schedule.startTime']].tail(5).mean()
df_tmp = df_ATL[df_ATL['game.startTime'] < df.loc[30]['schedule.startTime']].sort_values(by='game.startTime', ascending=False)[:5]
print(df_tmp.shape)
print('size: ', df_tmp.shape[0])
for i in range(5):
    if df_tmp.shape[0] < i:
        continue
    print(df_tmp.shape[0], i)
# Out:
# (2, 73)
# size:  2
# 2 0
# 2 1
# 2 2

# %%
df = df1.append(df2, ignore_index=True)

# %%
df[df['game.startTime'] < df.loc[5]['game.startTime']]
# Out:
#   game.awayTeamAbbreviation game.homeTeamAbbreviation  game.id  \
# 0                       ATL                       DAL    42078
# 1                       ATL                       CHA    42089
# 2                       ATL                       BRO    42107
# 3                       ATL                       MIA    42111
# 4                       ATL                       CHI    42134
#
#              game.startTime  stats.defense.blk  stats.defense.blkAgainst  \
# 0  2017-10-19T00:30:00.000Z                  6                         4
# 1  2017-10-20T23:00:00.000Z                  4                         4
# 2  2017-10-22T19:30:00.000Z                  2                         8
# 3  2017-10-23T23:30:00.000Z                  1                         6
# 4  2017-10-27T00:00:00.000Z                  5                         4
#
#    stats.defense.blkAgainstPerGame  stats.defense.blkPerGame  \
# 0                                4                         6
# 1                                4                         4
# 2                                8                         2
# 3                                6                         1
# 4                                4                         5
#
#    stats.defense.ptsAgainst  stats.defense.ptsAgainstPerGame   ...     \
# 0                       111                              111   ...
# 1                       109                              109   ...
# 2                       116                              116   ...
# 3                       104                              104   ...
# 4                        91                               91   ...
#
#    stats.rebounds.offReb  stats.rebounds.offRebPerGame  stats.rebounds.reb  \
# 0                     14                            14                  54
# 1                     15                            15                  49
# 2                     23                            23                  58
# 3                     11                            11                  47
# 4                      7                             7                  44
#
#    stats.rebounds.rebPerGame  stats.standings.gamesBack  \
# 0                         54                          0
# 1                         49                          0
# 2                         58                          0
# 3                         47                          0
# 4                         44                          0
#
#    stats.standings.losses  stats.standings.winPct  stats.standings.wins  \
# 0                       0                       1                     1
# 1                       1                       0                     0
# 2                       1                       0                     0
# 3                       1                       0                     0
# 4                       1                       0                     0
#
#    team.abbreviation  team.id
# 0                ATL       91
# 1                ATL       91
# 2                ATL       91
# 3                ATL       91
# 4                ATL       91
#
# [5 rows x 73 columns]

# %%
l1 = df.columns.values.tolist()
print(len(df.columns.values.tolist()))
for i in df.columns.values.tolist():
    print(i)
# Out:
# 73
# game.awayTeamAbbreviation
# game.homeTeamAbbreviation
# game.id
# game.startTime
# stats.defense.blk
# stats.defense.blkAgainst
# stats.defense.blkAgainstPerGame
# stats.defense.blkPerGame
# stats.defense.ptsAgainst
# stats.defense.ptsAgainstPerGame
# stats.defense.stl
# stats.defense.stlPerGame
# stats.defense.tov
# stats.defense.tovPerGame
# stats.fieldGoals.fg2PtAtt
# stats.fieldGoals.fg2PtAttPerGame
# stats.fieldGoals.fg2PtMade
# stats.fieldGoals.fg2PtMadePerGame
# stats.fieldGoals.fg2PtPct
# stats.fieldGoals.fg3PtAtt
# stats.fieldGoals.fg3PtAttPerGame
# stats.fieldGoals.fg3PtMade
# stats.fieldGoals.fg3PtMadePerGame
# stats.fieldGoals.fg3PtPct
# stats.fieldGoals.fgAtt
# stats.fieldGoals.fgAttPerGame
# stats.fieldGoals.fgMade
# stats.fieldGoals.fgMadePerGame
# stats.fieldGoals.fgPct
# stats.freeThrows.ftAtt
# stats.freeThrows.ftAttPerGame
# stats.freeThrows.ftMade
# stats.freeThrows.ftMadePerGame
# stats.freeThrows.ftPct
# stats.miscellaneous.ejections
# stats.miscellaneous.foulFlag1
# stats.miscellaneous.foulFlag1Drawn
# stats.miscellaneous.foulFlag1DrawnPerGame
# stats.miscellaneous.foulFlag1PerGame
# stats.miscellaneous.foulFlag2
# stats.miscellaneous.foulFlag2Drawn
# stats.miscellaneous.foulFlag2DrawnPerGame
# stats.miscellaneous.foulFlag2PerGame
# stats.miscellaneous.foulPers
# stats.miscellaneous.foulPersDrawn
# stats.miscellaneous.foulPersDrawnPerGame
# stats.miscellaneous.foulPersPerGame
# stats.miscellaneous.foulTech
# stats.miscellaneous.foulTechDrawn
# stats.miscellaneous.foulTechDrawnPerGame
# stats.miscellaneous.foulTechPerGame
# stats.miscellaneous.fouls
# stats.miscellaneous.foulsDrawn
# stats.miscellaneous.foulsDrawnPerGame
# stats.miscellaneous.foulsPerGame
# stats.miscellaneous.plusMinus
# stats.miscellaneous.plusMinusPerGame
# stats.offense.ast
# stats.offense.astPerGame
# stats.offense.pts
# stats.offense.ptsPerGame
# stats.rebounds.defReb
# stats.rebounds.defRebPerGame
# stats.rebounds.offReb
# stats.rebounds.offRebPerGame
# stats.rebounds.reb
# stats.rebounds.rebPerGame
# stats.standings.gamesBack
# stats.standings.losses
# stats.standings.winPct
# stats.standings.wins
# team.abbreviation
# team.id

# %%
df = df[df.columns.drop(list(df.filter(regex='PerGame')))]

# %%
l2 = df.columns.values.tolist()
print(len(df.columns.values.tolist()))
for i in df.columns.values.tolist():
    print(i)
# Out:
# 44
# game.awayTeamAbbreviation
# game.homeTeamAbbreviation
# game.id
# game.startTime
# stats.defense.blk
# stats.defense.blkAgainst
# stats.defense.ptsAgainst
# stats.defense.stl
# stats.defense.tov
# stats.fieldGoals.fg2PtAtt
# stats.fieldGoals.fg2PtMade
# stats.fieldGoals.fg2PtPct
# stats.fieldGoals.fg3PtAtt
# stats.fieldGoals.fg3PtMade
# stats.fieldGoals.fg3PtPct
# stats.fieldGoals.fgAtt
# stats.fieldGoals.fgMade
# stats.fieldGoals.fgPct
# stats.freeThrows.ftAtt
# stats.freeThrows.ftMade
# stats.freeThrows.ftPct
# stats.miscellaneous.ejections
# stats.miscellaneous.foulFlag1
# stats.miscellaneous.foulFlag1Drawn
# stats.miscellaneous.foulFlag2
# stats.miscellaneous.foulFlag2Drawn
# stats.miscellaneous.foulPers
# stats.miscellaneous.foulPersDrawn
# stats.miscellaneous.foulTech
# stats.miscellaneous.foulTechDrawn
# stats.miscellaneous.fouls
# stats.miscellaneous.foulsDrawn
# stats.miscellaneous.plusMinus
# stats.offense.ast
# stats.offense.pts
# stats.rebounds.defReb
# stats.rebounds.offReb
# stats.rebounds.reb
# stats.standings.gamesBack
# stats.standings.losses
# stats.standings.winPct
# stats.standings.wins
# team.abbreviation
# team.id

# %%
l_diff = [i for i in l1 if i not in l2]
print(len(l_diff))
for i in l_diff:
    print(i)
# Out:
# 29
# stats.defense.blkAgainstPerGame
# stats.defense.blkPerGame
# stats.defense.ptsAgainstPerGame
# stats.defense.stlPerGame
# stats.defense.tovPerGame
# stats.fieldGoals.fg2PtAttPerGame
# stats.fieldGoals.fg2PtMadePerGame
# stats.fieldGoals.fg3PtAttPerGame
# stats.fieldGoals.fg3PtMadePerGame
# stats.fieldGoals.fgAttPerGame
# stats.fieldGoals.fgMadePerGame
# stats.freeThrows.ftAttPerGame
# stats.freeThrows.ftMadePerGame
# stats.miscellaneous.foulFlag1DrawnPerGame
# stats.miscellaneous.foulFlag1PerGame
# stats.miscellaneous.foulFlag2DrawnPerGame
# stats.miscellaneous.foulFlag2PerGame
# stats.miscellaneous.foulPersDrawnPerGame
# stats.miscellaneous.foulPersPerGame
# stats.miscellaneous.foulTechDrawnPerGame
# stats.miscellaneous.foulTechPerGame
# stats.miscellaneous.foulsDrawnPerGame
# stats.miscellaneous.foulsPerGame
# stats.miscellaneous.plusMinusPerGame
# stats.offense.astPerGame
# stats.offense.ptsPerGame
# stats.rebounds.defRebPerGame
# stats.rebounds.offRebPerGame
# stats.rebounds.rebPerGame

# %%
l3 = []
for i in l_diff:
    l3.append(i.split('Pergame')[0])
print(len(l3))
# Out:
# 29

# %%
l4 = [i for i in l3 if i in l1]
print(len(l4))
# Out:
# 29

# %%
def combine_stats(team_name):
    stats_folder = 'team_game_logs_'
    file_name = 'team_game_log'
    season1 = '1718'
    season2 = '1819'
    file_type = '.xlsx'
    df1 = pd.read_excel("{}{}/{}_{}{}".format(stats_folder, season1, file_name, team_name, file_type))
    df2 = pd.read_excel("{}{}/{}_{}{}".format(stats_folder, season2, file_name, team_name, file_type))
    df = df1.append(df2, ignore_index=True)
    df = df[df.columns.drop(list(df.filter(regex='PerGame')))]
    output_folder = 'team_game_logs_combined'
    output_format = 'csv'
    l_id = df['team.id'].tolist()
    print(team_name, set(l_id))
    df.to_csv("{}/{}_{}.{}".format(output_folder, file_name, team_name, output_format), encoding='utf-8', index=False)
    # return df

# %%
df = combine_stats('ATL')

# %%
df.sort_values(by='game.startTime', ascending=False)[:5]
# Out:
#     game.awayTeamAbbreviation game.homeTeamAbbreviation  game.id  \
# 106                       WAS                       ATL    47926
# 105                       GSW                       ATL    47913
# 104                       ATL                       OKL    47894
# 103                       ATL                       CHA    47875
# 102                       ATL                       MIA    47871
#
#                game.startTime  stats.defense.blk  stats.defense.blkAgainst  \
# 106  2018-12-06T00:30:00.000Z                  4                         4
# 105  2018-12-04T00:30:00.000Z                  4                         8
# 104  2018-12-01T01:00:00.000Z                  3                         7
# 103  2018-11-29T00:00:00.000Z                  8                         5
# 102  2018-11-28T00:30:00.000Z                  7                         3
#
#      stats.defense.ptsAgainst  stats.defense.stl  stats.defense.tov  \
# 106                       131                 13                 17
# 105                       128                 10                 18
# 104                       124                 10                 15
# 103                       108                 11                 19
# 102                       113                 13                 24
#
#      stats.fieldGoals.fg2PtAtt   ...     stats.offense.pts  \
# 106                         54   ...                   117
# 105                         64   ...                   111
# 104                         47   ...                    80
# 103                         49   ...                    94
# 102                         49   ...                   115
#
#      stats.rebounds.defReb  stats.rebounds.offReb  stats.rebounds.reb  \
# 106                     35                      8                  43
# 105                     26                      9                  35
# 104                     24                      9                  33
# 103                     38                     16                  54
# 102                     36                     10                  46
#
#      stats.standings.gamesBack  stats.standings.losses  \
# 106                          0                       1
# 105                          0                       1
# 104                          0                       1
# 103                          0                       1
# 102                          0                       0
#
#      stats.standings.winPct  stats.standings.wins  team.abbreviation  team.id
# 106                       0                     0                ATL       91
# 105                       0                     0                ATL       91
# 104                       0                     0                ATL       91
# 103                       0                     0                ATL       91
# 102                       1                     1                ATL       91
#
# [5 rows x 44 columns]

# %%
print(df.loc[0])
df[(df['game.id'] == df.loc[0]['game.id'])]
# Out:
# game.awayTeamAbbreviation                                  ATL
# game.homeTeamAbbreviation                                  DAL
# game.id                                                  42078
# game.startTime                        2017-10-19T00:30:00.000Z
# stats.defense.blk                                            6
# stats.defense.blkAgainst                                     4
# stats.defense.ptsAgainst                                   111
# stats.defense.stl                                           11
# stats.defense.tov                                           13
# stats.fieldGoals.fg2PtAtt                                   76
# stats.fieldGoals.fg2PtMade                                  39
# stats.fieldGoals.fg2PtPct                                 51.3
# stats.fieldGoals.fg3PtAtt                                   18
# stats.fieldGoals.fg3PtMade                                   9
# stats.fieldGoals.fg3PtPct                                   50
# stats.fieldGoals.fgAtt                                      94
# stats.fieldGoals.fgMade                                     48
# stats.fieldGoals.fgPct                                    51.1
# stats.freeThrows.ftAtt                                      15
# stats.freeThrows.ftMade                                     12
# stats.freeThrows.ftPct                                      80
# stats.miscellaneous.ejections                                0
# stats.miscellaneous.foulFlag1                                0
# stats.miscellaneous.foulFlag1Drawn                           0
# stats.miscellaneous.foulFlag2                                0
# stats.miscellaneous.foulFlag2Drawn                           0
# stats.miscellaneous.foulPers                                18
# stats.miscellaneous.foulPersDrawn                           19
# stats.miscellaneous.foulTech                                18
# stats.miscellaneous.foulTechDrawn                            0
# stats.miscellaneous.fouls                                   20
# stats.miscellaneous.foulsDrawn                              19
# stats.miscellaneous.plusMinus                                6
# stats.offense.ast                                           20
# stats.offense.pts                                          117
# stats.rebounds.defReb                                       39
# stats.rebounds.offReb                                       14
# stats.rebounds.reb                                          54
# stats.standings.gamesBack                                    0
# stats.standings.losses                                       0
# stats.standings.winPct                                       1
# stats.standings.wins                                         1
# team.abbreviation                                          ATL
# team.id                                                     91
# Name: 0, dtype: object
#   game.awayTeamAbbreviation game.homeTeamAbbreviation  game.id  \
# 0                       ATL                       DAL    42078
#
#              game.startTime  stats.defense.blk  stats.defense.blkAgainst  \
# 0  2017-10-19T00:30:00.000Z                  6                         4
#
#    stats.defense.ptsAgainst  stats.defense.stl  stats.defense.tov  \
# 0                       111                 11                 13
#
#    stats.fieldGoals.fg2PtAtt   ...     stats.offense.pts  \
# 0                         76   ...                   117
#
#    stats.rebounds.defReb  stats.rebounds.offReb  stats.rebounds.reb  \
# 0                     39                     14                  54
#
#    stats.standings.gamesBack  stats.standings.losses  stats.standings.winPct  \
# 0                          0                       0                       1
#
#    stats.standings.wins  team.abbreviation  team.id
# 0                     1                ATL       91
#
# [1 rows x 44 columns]

# %%
l_id = df['team.id'].tolist()
print(set(l_id))
# Out:
# {91}

# %%
teams_all = '''ATL
BOS
BRO
CHA
CHI
CLE
DAL
DEN
DET
GSW
HOU
IND
LAC
LAL
MEM
MIA
MIL
MIN
NOP
NYK
OKL
ORL
PHI
PHX
POR
SAC
SAS
TOR
UTA
WAS
'''
teams = teams_all.splitlines()
for team in teams:
    combine_stats(team)
# Out:
# ATL {91}
# BOS {82}
# BRO {84}
# CHA {93}
# CHI {89}
# CLE {86}
# DAL {108}
# DEN {99}
# DET {88}
# GSW {101}
# HOU {109}
# IND {87}
# LAC {102}
# LAL {105}
# MEM {107}
# MIA {92}
# MIL {90}
# MIN {100}
# NOP {110}
# NYK {83}
# OKL {96}
# ORL {95}
# PHI {85}
# PHX {104}
# POR {97}
# SAC {103}
# SAS {106}
# TOR {81}
# UTA {98}
# WAS {94}
